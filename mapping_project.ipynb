# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('max_seq_item', None)

# %%
# First dataset is from the Washington Office of Superintendent of Public Instruction (OSPI),
# received via a public records request. Disclaimer from OSPI: "the information in the Excel sheet
# is only for recognized educational space and doesn’t contain portables because they are not recognized."
# I have already reduced the rows to select only the districts in King County and deleted a few columns

# %%
df_icos_king_county=pd.read_csv("icos_king_county.csv")

# %%
df_icos_king_county.head()

# %%
df_icos_king_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1724 entries, 0 to 1723
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District                             1724 non-null   object
#  1   Site                                 1724 non-null   object
#  2   Site_EQHazardLevel                   1724 non-null   object
#  3   Site_EQRiskLevel                     877 non-null    object
#  4   Site_Soil                            1724 non-null   object
#  5   Site_Liquefaction                    1724 non-null   object
#  6   Site_GroundMotionPercentile          1724 non-null   int64
#  7   Site_HasGeotechnicalStudy            1724 non-null   object
#  8   Building                             1724 non-null   object
#  9   Building_Type                        1724 non-null   object
#  10  Building_HasEvaluation               1724 non-null   object
# ...

# %%
df_icos_king_county.groupby(['District', 'Site', 'Site_EQRiskLevel']).ngroups

# %%
df_icos_king_county.groupby(['District', 'Site', 'Site_EQRiskLevel']).ngroups

# %%
df_icos_king_county['Site'].nunique()

# %%
df_icos_king_county.groupby(['Site', 'Site_EQRiskLevel']).ngroups

# %%
# I went into Excel to delete around 900 rows that no risk rating
df_icos_king_county_risk=pd.read_csv("icos_king_county_risk.csv")

# %%
df_icos_king_county_risk.head()
# Out:
#       District                        Site Site_EQHazardLevel  \
# 0  Federal Way  Adelaide Elementary School           Moderate
# 1  Federal Way  Adelaide Elementary School           Moderate
# 2  Federal Way  Adelaide Elementary School           Moderate
# 3  Federal Way  Adelaide Elementary School           Moderate
# 4  Federal Way         Decatur High School           Moderate
#
#   Site_EQRiskLevel                              Site_Soil Site_Liquefaction  \
# 0        Very High  Very Dense Soil/Soft Rock - Firm Soil          Very Low
# 1        Very High  Very Dense Soil/Soft Rock - Firm Soil          Very Low
# 2        Very High  Very Dense Soil/Soft Rock - Firm Soil          Very Low
# 3        Very High  Very Dense Soil/Soft Rock - Firm Soil          Very Low
# 4        Very High          Very Dense Soil and Soft Rock          Very Low
#
#    Site_GroundMotionPercentile Site_HasGeotechnicalStudy       Building  \
# ...

# %%
df_icos_king_county_risk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 877 entries, 0 to 876
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   District                             877 non-null    object
#  1   Site                                 877 non-null    object
#  2   Site_EQHazardLevel                   877 non-null    object
#  3   Site_EQRiskLevel                     877 non-null    object
#  4   Site_Soil                            877 non-null    object
#  5   Site_Liquefaction                    877 non-null    object
#  6   Site_GroundMotionPercentile          877 non-null    int64
#  7   Site_HasGeotechnicalStudy            877 non-null    object
#  8   Building                             877 non-null    object
#  9   Building_Type                        877 non-null    object
#  10  Building_HasEvaluation               877 non-null    object
# ...

# %%
df_icos_king_county_risk.groupby(['District', 'Site', 'Site_EQRiskLevel']).ngroups
# this result doesn't make sense, it is the same number as the full dataset
# before I deleted 900 or so rows with no risk rating
# Out:
# 226

# %%
df_icos_king_county_risk['Site'].nunique()
# this result doesn't make sense, it is the same number as the full dataset
# before I deleted 900 or so rows with no risk rating
# Out:
# 224

# %%
df_icos_king_county_high_risk=pd.read_csv("icos_king_county_high_risk.csv")

# %%
df_icos_king_county_high_risk.head()
# Out:
#       District                        Site Site_EQHazardLevel  \
# 0  Federal Way   Camelot Elementary School           Moderate
# 1  Federal Way   Camelot Elementary School           Moderate
# 2  Federal Way   Camelot Elementary School           Moderate
# 3  Federal Way  Federal Way Public Academy           Moderate
# 4  Federal Way  Federal Way Public Academy           Moderate
#
#   Site_EQRiskLevel                      Site_Soil Site_Liquefaction  \
# 0             High  Very Dense Soil and Soft Rock          Very Low
# 1             High  Very Dense Soil and Soft Rock          Very Low
# 2             High  Very Dense Soil and Soft Rock          Very Low
# 3             High  Very Dense Soil and Soft Rock          Very Low
# 4             High  Very Dense Soil and Soft Rock          Very Low
#
#    Site_GroundMotionPercentile Site_HasGeotechnicalStudy       Building  \
# 0                           68                       Yes  Main Building
# ...

# %%
df_icos_king_county_high_risk.groupby(['District', 'Site', 'Site_EQRiskLevel']).ngroups
# Out:
# 91

# %%
df_icos_king_county_high_risk['Site'].nunique()
# Out:
# 91

# %%
df_icos_king_county_high_risk_sites = df_icos_king_county_high_risk[['District', 'Site', 'Site_EQRiskLevel']].drop_duplicates()

# %%
df_icos_king_county_high_risk_sites.head()
# Out:
#        District                        Site Site_EQRiskLevel
# 0   Federal Way   Camelot Elementary School             High
# 3   Federal Way  Federal Way Public Academy             High
# 5   Federal Way       Illahee Middle School             High
# 19  Federal Way          Kilo Middle School             High
# 31  Federal Way         Nautilus K-8 School             High

# %%
df_icos_king_county_high_risk_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 0 to 503
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   District          91 non-null     object
#  1   Site              91 non-null     object
#  2   Site_EQRiskLevel  91 non-null     object
# dtypes: object(3)
# memory usage: 2.8+ KB

# %%
df_icos_king_county_high_risk_sites
# Out:
#               District                                            Site  \
# 0          Federal Way                       Camelot Elementary School
# 3          Federal Way                      Federal Way Public Academy
# 5          Federal Way                           Illahee Middle School
# 19         Federal Way                              Kilo Middle School
# 31         Federal Way                             Nautilus K-8 School
# 42                Kent                       Horizon Elementary School
# 45                Kent                 Martin Sortun Elementary School
# 48             Seattle                Bailey Gatzert Elementary School
# 49             Seattle                     Hawthorne Elementary School
# 50             Seattle                McDonald Int'l Elementary School
# 54             Seattle                  Olympic View Elementary School
# 57             Seattle                            Whitworth (Orca K-8)
# ...

# %%
#df_icos['Site_EQRiskLevel'].astype(str)
df_icos_king_county_high_risk_sites["District"].value_counts()
# Out:
# District
# Seattle              28
# Kent                 19
# Highline             15
# Federal Way          12
# Shoreline            10
# Snoqualmie Valley     2
# Northshore            2
# Renton                2
# Vashon Island         1
# Name: count, dtype: int64

# %%
df_icos_king_county_high_risk_sites.to_csv('df_icos_king_county_high_risk_sites.csv', sep=',', index=False, encoding='utf-8')

# %%
# In Excel, I deleted a few schools labeled "old" and the "high" risk ones
# then I manually added plotting info from the the Washington Geospatial Open Data Portal
# https://geo.wa.gov/datasets/23bbd746f9924c149681815cfd2a6300/explore?location=47.266088%2C-120.802250%2C7.02&showTable=true
# I plan to re-do all of the above in pandas later

# %%
king_county_mapping=pd.read_csv("king_county_mapping.csv")

# %%
king_county_mapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   District   64 non-null     object
#  1   Site       64 non-null     object
#  2   Latitude   64 non-null     float64
#  3   Longitude  64 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 2.1+ KB

# %%
king_county_mapping["District"].value_counts()
# Out:
# District
# Seattle              19
# Kent                 16
# Highline             12
# Shoreline             7
# Federal Way           6
# Renton                2
# Snoqualmie Valley     1
# Vashon Island         1
# Name: count, dtype: int64

# %%
king_county_mapping_v2=pd.read_csv("king_county_mapping_v2.csv")

# %%
king_county_mapping_v2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   District    63 non-null     object
#  1   Site        63 non-null     object
#  2   Age Level   63 non-null     object
#  3   Enrollment  63 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 2.1+ KB

# %%
king_county_mapping_v3 = king_county_mapping_v2.groupby(['Age Level'])['Enrollment'].count()
king_county_mapping_v3
# Out:
# Age Level
# Elem           34
# HS             14
# K-8             3
# Middle         10
# Middle & HS     1
# PS              1
# Name: Enrollment, dtype: int64

# %%
# king_county_mapping_v2['Enrollment'].astype(str).astype(int)

# %%
king_county_mapping_v4 = king_county_mapping_v2.groupby(['Age Level'])['Enrollment'].sum()
king_county_mapping_v4
# Out:
# Age Level
# Elem           13225
# HS             17069
# K-8              740
# Middle          6607
# Middle & HS      237
# PS               252
# Name: Enrollment, dtype: int64

# %%
king_county_mapping_v5 = king_county_mapping_v2.groupby(['District'])['Enrollment'].sum()
king_county_mapping_v5
# Out:
# District
# Federal Way           3722
# Highline              5765
# Kent                 10910
# Renton                3146
# Seattle              10291
# Shoreline             3326
# Snoqualmie Valley      462
# Vashon Island          508
# Name: Enrollment, dtype: int64

# %%
# it is surprising that Kent, with a smaller population than Seattle, has the most
# according to Wikipedia, it has a large school district that includes schools
# outside of Kent https://en.wikipedia.org/wiki/Kent,_Washington
